# %% [markdown]
# <a href="https://colab.research.google.com/github/Cjeyms/CCMACLRL_EXERCISES_COM222ML/blob/main/Exercise8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 8: Create your own personal face recognition using SVM

# %% [markdown]
# ## Instructions:
#
# Create a directory in your google drive using this folder structure
#
# ```
# My Drive
# - Images
#   - Train
#     - Elizer
#     - Eliza
#   - Test
# ```
#
# - Upload 30 images of your self (selfied are recommended) in the Train folder
# - Upload 30 images of your partner in the Train folder
# - Upload 10 images of yourself and your partner in the Test Folder
# - Use **.png** or **.jpg** or **.jpeg** images files

# %%
pip install numpy opencv-python scikit-learn
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %% [markdown]
# ## Import libraries

# %%
import os
import cv2
import numpy as np
from PIL import Image  # PIL is used to load the image
import matplotlib.pyplot as plt

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Display one raw image directly from your drive

# %%
# put your answer here
def displayImage(image_path):
  # Path to your image file in Google Drive
  image = Image.open(image_path)

  # Display the image using matplotlib
  plt.imshow(image)
  plt.axis('on')  # Hide axes for cleaner display
  plt.show()

# %% [markdown]
# ## Load the images from your drive and apply preprocessing to your raw images

# %%
displayImage('/content/drive/My Drive/Images/Train/JAMES/9EEEED9B-D88A-4E7C-874C-DA12C7EA8EC5.jpg')

# %% [markdown]
# ## Display one pre-processed image from the training set

# %%
def load_images_from_folder(folder):
    images = []
    labels = []
    for label, person in enumerate(os.listdir(folder)):
        person_folder = os.path.join(folder, person)
        person_name = os.path.basename(person_folder)
        for filename in os.listdir(person_folder):
            img_path = os.path.join(person_folder, filename)

            # Check if the file exists before attempting to read it
            if not os.path.exists(img_path):
                print(f"Warning: File not found: {img_path}")
                continue

            img = cv2.imread(img_path)

            # Check if the image was loaded successfully
            if img is None:
                print(f"Warning: Failed to load image: {img_path}")
                continue

            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
            img = cv2.resize(img, (100, 100))  # Resize to 100x100 pixels
            images.append(img.flatten())  # Flatten the image
            labels.append(person_name)
    return np.array(images), np.array(labels)

# %%
images, labels = load_images_from_folder('/content/drive/My Drive/Images/Train')
# Out:
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_5889.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_5901.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_5608.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_2354.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7203.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7204.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7205.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7212.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_2353.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_5893.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_5607.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_6528.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_5602.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_5596.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_8536.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_5594.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_9313.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_5595.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_4875.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_4874.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7202.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7206.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7201.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_4212.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_4211.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7209.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_6059.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7211.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_6058.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_4876.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7210.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_5388.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_5395.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7130.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7135.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7207.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_9742.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7208.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_3720.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7200 (1).HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_7200.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_5400.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_8385.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_8386.HEIC
# Warning: Failed to load image: /content/drive/My Drive/Images/Train/JAMES/IMG_6727.HEIC

# %% [markdown]
# ## Display ten pre-processed images from the training set

# %%
image = images[0].reshape(100,100)  # Access the first image
name = labels[0]  # Get the name corresponding to the image

# Display the image
plt.imshow(image, cmap="gray")
plt.title(name)
plt.axis('on')  # Hide axes
plt.show()

# %%
num_faces = 10

fig, axes = plt.subplots(2, 5, figsize=(15, 6))  # 2 rows and 5 columns
axes = axes.flatten()  # Flatten the array of axes for easy indexing

# Loop to display the images
for i in range(num_faces):
    image = images[i].reshape(100,100)  # Access the i-th image
    name = labels[i]  # Get the name corresponding to the image

    axes[i].imshow(image, cmap='gray')  # Show the image
    axes[i].set_title(name)  # Set the title to the name
    axes[i].axis('on')  # Hide axes

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Split your data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %% [markdown]
# ## Train your SVM model

# %%
from sklearn import svm

model = svm.SVC(gamma='scale')  # You can choose different kernels like 'linear', 'rbf', etc.
model.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# ## Evaluate your model

# %%
# put your answer here
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 96.00%

# %% [markdown]
# ## Test your model using images not in your training set

# %% [markdown]
# Test one image of yourself

# %%
# put your answer here
def predict_image(img_path, model):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (100, 100)).flatten().reshape(1, -1)  # Flatten and reshape for prediction
    prediction = model.predict(img)
    return prediction

# %% [markdown]
# Test one image of your partner

# %%
# put your answer here
def predict_images_in_folder(folder_path, model):
    for filename in os.listdir(folder_path):
        img_path = os.path.join(folder_path, filename)

        # Check if it's a file (not a subdirectory)
        if os.path.isfile(img_path):
            result = predict_image(img_path, model)  # Assuming predict_image function is defined
            print(f'Image: {filename}, Predicted label: {result[0]}')  # result[0] to get the label
            displayImage(img_path)  # Assuming displayImage function is defined

# Call the function to predict on images in the Test folder
predict_images_in_folder('/content/drive/My Drive/Images/Test', model)
# Out:
# Image: Image.jpg, Predicted label: JAMES
# Image: Copy of TEST 3.JPG, Predicted label: AARON
